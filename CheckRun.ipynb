# %% [markdown]
# <a href="https://colab.research.google.com/github/absolutelydawn/TestNeoX/blob/main/CheckRun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python 3.8 설치
# !apt-get update -y
# !apt-get install -y python3.8

# 기존 Python 버전 제거 및 Python 3.8으로 설정
# !update-alternatives --remove-all python
# !update-alternatives --install /usr/bin/python python /usr/bin/python3.8 1
# !update-alternatives --config python

# PyTorch 최신버전 설치
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio

# Transformers 라이브러리 설치
# !pip install transformers

# EleutherAI의 사전 훈련된 모델과 tokenizer 사용
from transformers import GPTNeoForCausalLM, GPT2Tokenizer

# 모델과 tokenizer 불러오기
model = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")

# 예제 문장 생성
input_text = "Once upon a time,"
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# 모델로 문장 생성하기
output = model.generate(input_ids, max_length=100, num_return_sequences=1)
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(generated_text)
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.8 is already the newest version (3.8.17-1+jammy1).
# ...
